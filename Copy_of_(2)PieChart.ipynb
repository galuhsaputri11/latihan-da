# %% [markdown]
# <a href="https://colab.research.google.com/github/galuhsaputri11/latihan-da/blob/main/Copy_of_(2)PieChart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Importing Libraries and Data

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

t_mov= pd.read_csv('https://raw.githubusercontent.com/galuhsaputri11/latihan-da/main/Dataset/types_movies.csv')

# %%
# !wget -O types_movies.csv https://raw.githubusercontent.com/galuhsaputri11/latihan-da/main/Dataset/types_movies.csv
# Out:
# --2023-10-17 03:09:16--  https://raw.githubusercontent.com/galuhsaputri11/latihan-da/main/Dataset/types_movies.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67 [text/plain]
# Saving to: ‘types_movies.csv’
#
# types_movies.csv    100%[===================>]      67  --.-KB/s    in 0s
#
# 2023-10-17 03:09:16 (1.95 MB/s) - ‘types_movies.csv’ saved [67/67]

# %%
t_mov
# Out:
#     Sector  Percentage
# 0   Sci-Fi          20
# 1    Drama          35
# 2   Action          25
# 3   Comedy           5
# 4  Romance          15

# %% [markdown]
# ### Pie Chart
# Pie chart shows distribution of data based on proportion of pie occupied.

# %%
plt.pie(t_mov['Percentage'],
        labels=t_mov['Sector'])

plt.axis('equal')

plt.show()

# %% [markdown]
# ### Pie chart components
# * <b>wedges:</b> A list of Patch objects representing each wedge
# * <b>texts:</b> List of Text objects representing the labels
# * <b>autotexts:</b> List of Text objects for the numeric values - this is only availabe if the autopct value for the pie chart is not None

# %%
wedges, texts, autotexts = plt.pie(t_mov['Percentage'],
                                    labels=t_mov['Sector'],
                                    autopct='%.2f')

plt.axis('equal')

print('Wedges: ', wedges)
print('Texts: ', texts)
print('Autotexts: ', autotexts)
# Out:
# Wedges:  [<matplotlib.patches.Wedge object at 0x7f1e77407e50>, <matplotlib.patches.Wedge object at 0x7f1e77407970>, <matplotlib.patches.Wedge object at 0x7f1e77404940>, <matplotlib.patches.Wedge object at 0x7f1e774063b0>, <matplotlib.patches.Wedge object at 0x7f1e768087f0>]
# Texts:  [Text(0.8899186877588753, 0.6465637858537406, 'Sci-Fi'), Text(-0.7778174593052023, 0.7778174593052024, 'Drama'), Text(-0.49938956806635254, -0.9801071672559598, 'Action'), Text(0.4993895336547568, -0.9801071847895437, 'Comedy'), Text(0.9801071789450159, -0.49938954512528877, 'Romance')]
# Autotexts:  [Text(0.4854101933230228, 0.35267115592022213, '20.00'), Text(-0.42426406871192845, 0.4242640687119285, '35.00'), Text(-0.2723943098543741, -0.5346039094123416, '25.00'), Text(0.27239429108441277, -0.5346039189761147, '5.00'), Text(0.5346039157881904, -0.27239429734106657, '15.00')]

# %% [markdown]
# #### Pie chart customizations
#  We set the values for the colors and autopct properties. The latter sets the format for the values to be displayed.

# %%
colors = ['darkorange', 'sandybrown', 'darksalmon', 'orangered','chocolate']

plt.pie(t_mov['Percentage'],
        labels=t_mov['Sector'],
        colors=colors,
        autopct='%.2f')

plt.axis('equal')

plt.show()

# %% [markdown]
# #### The explode property
# To highlight a particular wedge of the pie chart, we use explode to separate it from the rest of the chart.
#
# The value for "explode" represents the fraction of the radius with which to offset each wedge.

# %%
explode = (0, 0.1, 0, 0, 0.3)

plt.pie(t_mov['Percentage'],
        labels=t_mov['Sector'],
        colors=colors,
        autopct='%.2f',
        explode=explode)

plt.axis('equal')

plt.show()
