# %% [markdown]
# <a href="https://colab.research.google.com/github/galuhsaputri11/latihan-da/blob/main/Copy_of_Data_Manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Manipulation Tasks

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !wget -O My Uber Drives - 2016.csv https://raw.githubusercontent.com/jumadi-cloud/Fundamental-Python/main/Dataset/My%20Uber%20Drives%20-%202016%20(1).csv

# %% [markdown]
# ## 1. Selecting/Indexing

# %%
data = pd.read_csv("/content/My Uber Drives - 2016.csv")
data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %% [markdown]
# ### Positional Indexing

# %% [markdown]
# #### `loc` and `iloc`

# %%
data.iloc[2:5, :]    # baris 1- 3 dan semua kolom
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
data.iloc[0:3, 3:5]
# Out:
#         START*        STOP*
# 0  Fort Pierce  Fort Pierce
# 1  Fort Pierce  Fort Pierce
# 2  Fort Pierce  Fort Pierce

# %%
data.iloc[:, 3:6]
# Out:
#                 START*             STOP*   MILES*
# 0          Fort Pierce       Fort Pierce      5.1
# 1          Fort Pierce       Fort Pierce      5.0
# 2          Fort Pierce       Fort Pierce      4.8
# 3          Fort Pierce       Fort Pierce      4.7
# 4          Fort Pierce   West Palm Beach     63.7
# ...                ...               ...      ...
# 1151           Kar?chi  Unknown Location      3.9
# 1152  Unknown Location  Unknown Location     16.2
# 1153        Katunayake           Gampaha      6.4
# 1154           Gampaha         Ilukwatta     48.2
# 1155               NaN               NaN  12204.7
#
# [1156 rows x 3 columns]

# %%
data.iloc[1:3, 3:6]
# Out:
#         START*        STOP*  MILES*
# 1  Fort Pierce  Fort Pierce     5.0
# 2  Fort Pierce  Fort Pierce     4.8

# %% [markdown]
# ## Label Indexing

# %%
data.loc[0:1, ["START*"]]
# Out:
#         START*
# 0  Fort Pierce
# 1  Fort Pierce

# %%
data.loc[0:5, :"START*"]
# Out:
#       START_DATE*       END_DATE* CATEGORY*           START*
# 0  1/1/2016 21:11  1/1/2016 21:17  Business      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business      Fort Pierce
# 5  1/6/2016 17:15  1/6/2016 17:19  Business  West Palm Beach

# %%
data.loc[:, ["START_DATE*", "MILES*"]]
# Out:
#            START_DATE*   MILES*
# 0       1/1/2016 21:11      5.1
# 1        1/2/2016 1:25      5.0
# 2       1/2/2016 20:25      4.8
# 3       1/5/2016 17:31      4.7
# 4       1/6/2016 14:42     63.7
# ...                ...      ...
# 1151  12/31/2016 13:24      3.9
# 1152  12/31/2016 15:03     16.2
# 1153  12/31/2016 21:32      6.4
# 1154  12/31/2016 22:08     48.2
# 1155            Totals  12204.7
#
# [1156 rows x 2 columns]

# %%
data.loc[:, ["START_DATE*", "MILES*"]].head()
# Out:
#       START_DATE*  MILES*
# 0  1/1/2016 21:11     5.1
# 1   1/2/2016 1:25     5.0
# 2  1/2/2016 20:25     4.8
# 3  1/5/2016 17:31     4.7
# 4  1/6/2016 14:42    63.7

# %%
a = data.loc[:, "START*"]
a
# Out:
# 0            Fort Pierce
# 1            Fort Pierce
# 2            Fort Pierce
# 3            Fort Pierce
# 4            Fort Pierce
#               ...
# 1151             Kar?chi
# 1152    Unknown Location
# 1153          Katunayake
# 1154             Gampaha
# 1155                 NaN
# Name: START*, Length: 1156, dtype: object

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
b = data.loc[:, ["START*"]].head()
b
# Out:
#         START*
# 0  Fort Pierce
# 1  Fort Pierce
# 2  Fort Pierce
# 3  Fort Pierce
# 4  Fort Pierce

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Latihan 3

# %% [markdown]
# ### Soal 1 pilih kolom START_DATE*, START*, STOP*

# %%
data.loc[:, ["START_DATE*", "START*", "STOP*"]]
# Out:
#            START_DATE*            START*             STOP*
# 0       1/1/2016 21:11       Fort Pierce       Fort Pierce
# 1        1/2/2016 1:25       Fort Pierce       Fort Pierce
# 2       1/2/2016 20:25       Fort Pierce       Fort Pierce
# 3       1/5/2016 17:31       Fort Pierce       Fort Pierce
# 4       1/6/2016 14:42       Fort Pierce   West Palm Beach
# ...                ...               ...               ...
# 1151  12/31/2016 13:24           Kar?chi  Unknown Location
# 1152  12/31/2016 15:03  Unknown Location  Unknown Location
# 1153  12/31/2016 21:32        Katunayake           Gampaha
# 1154  12/31/2016 22:08           Gampaha         Ilukwatta
# 1155            Totals               NaN               NaN
#
# [1156 rows x 3 columns]

# %% [markdown]
# ### Soal 2 pilih 10 baris pertama dari kolom soal nomor 1

# %%
data.loc[:9, ["START_DATE*", "START*", "STOP*"]]
# Out:
#        START_DATE*           START*            STOP*
# 0   1/1/2016 21:11      Fort Pierce      Fort Pierce
# 1    1/2/2016 1:25      Fort Pierce      Fort Pierce
# 2   1/2/2016 20:25      Fort Pierce      Fort Pierce
# 3   1/5/2016 17:31      Fort Pierce      Fort Pierce
# 4   1/6/2016 14:42      Fort Pierce  West Palm Beach
# 5   1/6/2016 17:15  West Palm Beach  West Palm Beach
# 6   1/6/2016 17:30  West Palm Beach       Palm Beach
# 7   1/7/2016 13:27             Cary             Cary
# 8   1/10/2016 8:05             Cary      Morrisville
# 9  1/10/2016 12:17          Jamaica         New York

# %% [markdown]
# ## 2. Filtering

# %%
df1 = data.loc[data["MILES*"] > 10, ["MILES*"]]

# %%
df1
# Out:
#        MILES*
# 4        63.7
# 9        16.5
# 10       10.8
# 22       15.1
# 23       11.2
# ...       ...
# 1134     11.9
# 1144     12.9
# 1152     16.2
# 1154     48.2
# 1155  12204.7
#
# [316 rows x 1 columns]

# %%
df1 = data.loc[data["MILES*"] > 10, ["START*"]]

# %%
df1
# Out:
#                 START*
# 4          Fort Pierce
# 9              Jamaica
# 10            New York
# 22            New York
# 23            Downtown
# ...                ...
# 1134  Unknown Location
# 1144  Unknown Location
# 1152  Unknown Location
# 1154           Gampaha
# 1155               NaN
#
# [316 rows x 1 columns]

# %%
df1 = data.loc[data["START*"] == "New York"]

# %%
df1
# Out:
#          START_DATE*        END_DATE* CATEGORY*    START*             STOP*  \
# 10   1/10/2016 15:08  1/10/2016 15:51  Business  New York            Queens
# 22   1/12/2016 16:02  1/12/2016 17:00  Business  New York     Queens County
# 106  2/14/2016 16:35  2/14/2016 17:02  Business  New York  Long Island City
# 423  6/10/2016 15:19  6/10/2016 16:28  Business  New York           Jamaica
#
#      MILES* PURPOSE*
# 10     10.8  Meeting
# 22     15.1  Meeting
# 106    13.0  Meeting
# 423    16.3  Meeting

# %%
# memperlihatkan semua kolom yang miles-nya lebih dari 10
data.loc[data["MILES*"] > 10]
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 9      1/10/2016 12:17   1/10/2016 12:44  Business           Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business          New York
# 22     1/12/2016 16:02   1/12/2016 17:00  Business          New York
# 23     1/13/2016 13:54   1/13/2016 14:07  Business          Downtown
# ...                ...               ...       ...               ...
# 1134  12/29/2016 11:28  12/29/2016 12:00  Business  Unknown Location
# 1144  12/29/2016 23:14  12/29/2016 23:47  Business  Unknown Location
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 4      West Palm Beach     63.7  Customer Visit
# ...

# %%
# memperlihatkan semua kolom dengan "START* = New York"
data.loc[data["START*"] == "New York"]
# Out:
#          START_DATE*        END_DATE* CATEGORY*    START*             STOP*  \
# 10   1/10/2016 15:08  1/10/2016 15:51  Business  New York            Queens
# 22   1/12/2016 16:02  1/12/2016 17:00  Business  New York     Queens County
# 106  2/14/2016 16:35  2/14/2016 17:02  Business  New York  Long Island City
# 423  6/10/2016 15:19  6/10/2016 16:28  Business  New York           Jamaica
#
#      MILES* PURPOSE*
# 10     10.8  Meeting
# 22     15.1  Meeting
# 106    13.0  Meeting
# 423    16.3  Meeting

# %%
df1 = data.loc[data["START*"] == "New York", ["MILES*", "STOP*"]]

# %%
df1
# Out:
#      MILES*             STOP*
# 10     10.8            Queens
# 22     15.1     Queens County
# 106    13.0  Long Island City
# 423    16.3           Jamaica

# %%
# memperlihatkan semua kolom yang didalamnya terdapat tulisan "Cary" dan "New York"
st = data[data["START*"].isin(["Cary","New York"])]
# tampilkan 10 baris pertama
st.head(n=10)
# Out:
#         START_DATE*        END_DATE* CATEGORY*    START*          STOP*  \
# 7    1/7/2016 13:27   1/7/2016 13:33  Business      Cary           Cary
# 8    1/10/2016 8:05   1/10/2016 8:25  Business      Cary    Morrisville
# 10  1/10/2016 15:08  1/10/2016 15:51  Business  New York         Queens
# 22  1/12/2016 16:02  1/12/2016 17:00  Business  New York  Queens County
# 28  1/15/2016 11:43  1/15/2016 12:03  Business      Cary         Durham
# 30  1/18/2016 14:55  1/18/2016 15:06  Business      Cary           Cary
# 34  1/20/2016 10:36  1/20/2016 11:11  Business      Cary        Raleigh
# 37  1/21/2016 14:25  1/21/2016 14:29  Business      Cary           Cary
# 38  1/21/2016 14:43  1/21/2016 14:51  Business      Cary           Cary
# 39  1/21/2016 16:01  1/21/2016 16:06  Business      Cary           Cary
#
#     MILES*         PURPOSE*
# 7      0.8          Meeting
# 8      8.3          Meeting
# 10    10.8          Meeting
# 22    15.1          Meeting
# 28    10.4   Meal/Entertain
# ...

# %%
st.loc[0:5, :]
# Out:
# Empty DataFrame
# Columns: [START_DATE*, END_DATE*, CATEGORY*, START*, STOP*, MILES*, PURPOSE*]
# Index: []

# %%
st.iloc[0:5, :]
# Out:
#         START_DATE*        END_DATE* CATEGORY*    START*          STOP*  \
# 7    1/7/2016 13:27   1/7/2016 13:33  Business      Cary           Cary
# 8    1/10/2016 8:05   1/10/2016 8:25  Business      Cary    Morrisville
# 10  1/10/2016 15:08  1/10/2016 15:51  Business  New York         Queens
# 22  1/12/2016 16:02  1/12/2016 17:00  Business  New York  Queens County
# 28  1/15/2016 11:43  1/15/2016 12:03  Business      Cary         Durham
#
#     MILES*        PURPOSE*
# 7      0.8         Meeting
# 8      8.3         Meeting
# 10    10.8         Meeting
# 22    15.1         Meeting
# 28    10.4  Meal/Entertain

# %%
st.reset_index()
# Out:
#      index       START_DATE*         END_DATE* CATEGORY*    START*  \
# 0        7    1/7/2016 13:27    1/7/2016 13:33  Business      Cary
# 1        8    1/10/2016 8:05    1/10/2016 8:25  Business      Cary
# 2       10   1/10/2016 15:08   1/10/2016 15:51  Business  New York
# 3       22   1/12/2016 16:02   1/12/2016 17:00  Business  New York
# 4       28   1/15/2016 11:43   1/15/2016 12:03  Business      Cary
# ..     ...               ...               ...       ...       ...
# 200   1049  12/13/2016 20:20  12/13/2016 20:29  Business      Cary
# 201   1050  12/14/2016 16:52  12/14/2016 17:10  Business      Cary
# 202   1051  12/14/2016 17:22  12/14/2016 17:34  Business      Cary
# 203   1052  12/14/2016 17:50  12/14/2016 18:00  Business      Cary
# 204   1054  12/15/2016 14:20  12/15/2016 14:54  Business      Cary
#
#              STOP*  MILES*        PURPOSE*
# 0             Cary     0.8         Meeting
# 1      Morrisville     8.3         Meeting
# ...

# %%
st.reset_index(inplace = True)

# %%
st
# Out:
#      index       START_DATE*         END_DATE* CATEGORY*    START*  \
# 0        7    1/7/2016 13:27    1/7/2016 13:33  Business      Cary
# 1        8    1/10/2016 8:05    1/10/2016 8:25  Business      Cary
# 2       10   1/10/2016 15:08   1/10/2016 15:51  Business  New York
# 3       22   1/12/2016 16:02   1/12/2016 17:00  Business  New York
# 4       28   1/15/2016 11:43   1/15/2016 12:03  Business      Cary
# ..     ...               ...               ...       ...       ...
# 200   1049  12/13/2016 20:20  12/13/2016 20:29  Business      Cary
# 201   1050  12/14/2016 16:52  12/14/2016 17:10  Business      Cary
# 202   1051  12/14/2016 17:22  12/14/2016 17:34  Business      Cary
# 203   1052  12/14/2016 17:50  12/14/2016 18:00  Business      Cary
# 204   1054  12/15/2016 14:20  12/15/2016 14:54  Business      Cary
#
#              STOP*  MILES*        PURPOSE*
# 0             Cary     0.8         Meeting
# 1      Morrisville     8.3         Meeting
# ...

# %%
st.reset_index(inplace = True, drop = True)

# %%
st
# Out:
#      index       START_DATE*         END_DATE* CATEGORY*    START*  \
# 0        7    1/7/2016 13:27    1/7/2016 13:33  Business      Cary
# 1        8    1/10/2016 8:05    1/10/2016 8:25  Business      Cary
# 2       10   1/10/2016 15:08   1/10/2016 15:51  Business  New York
# 3       22   1/12/2016 16:02   1/12/2016 17:00  Business  New York
# 4       28   1/15/2016 11:43   1/15/2016 12:03  Business      Cary
# ..     ...               ...               ...       ...       ...
# 200   1049  12/13/2016 20:20  12/13/2016 20:29  Business      Cary
# 201   1050  12/14/2016 16:52  12/14/2016 17:10  Business      Cary
# 202   1051  12/14/2016 17:22  12/14/2016 17:34  Business      Cary
# 203   1052  12/14/2016 17:50  12/14/2016 18:00  Business      Cary
# 204   1054  12/15/2016 14:20  12/15/2016 14:54  Business      Cary
#
#              STOP*  MILES*        PURPOSE*
# 0             Cary     0.8         Meeting
# 1      Morrisville     8.3         Meeting
# ...

# %%
data[data["START*"].isin(["Cary","New York"])].shape
# Out:
# (205, 7)

# %%
data[data["STOP*"].isin(["Cary", "Morrisville"])].shape
# Out:
# (287, 7)

# %% [markdown]
# ## Latihan 4

# %% [markdown]
# ### Soal 1 Perlihatkan semua kolom yang lebih besar dari 10 miles dan berasal dari New York dan Morrisville

# %%
filter1 = data["START*"].isin(["New York", "Morrisville"])
data[filter1]
# Out:
#            START_DATE*         END_DATE* CATEGORY*       START*  \
# 10     1/10/2016 15:08   1/10/2016 15:51  Business     New York
# 22     1/12/2016 16:02   1/12/2016 17:00  Business     New York
# 27      1/15/2016 0:41    1/15/2016 1:01  Business  Morrisville
# 68       2/4/2016 9:37    2/4/2016 10:09  Business  Morrisville
# 82      2/7/2016 20:22    2/7/2016 20:40  Business  Morrisville
# ...                ...               ...       ...          ...
# 1021   12/4/2016 20:23   12/4/2016 20:34  Business  Morrisville
# 1039  12/10/2016 22:09  12/10/2016 22:21  Business  Morrisville
# 1041  12/11/2016 19:05  12/11/2016 19:15  Business  Morrisville
# 1047  12/12/2016 20:48  12/12/2016 20:57  Business  Morrisville
# 1053  12/14/2016 20:24  12/14/2016 20:40  Business  Morrisville
#
#               STOP*  MILES*         PURPOSE*
# 10           Queens    10.8          Meeting
# 22    Queens County    15.1          Meeting
# 27             Cary     8.0  Errand/Supplies
# ...

# %%
coba = data[filter1].loc[data["MILES*"] > 10]
coba
# Out:
#           START_DATE*         END_DATE* CATEGORY*       START*  \
# 10    1/10/2016 15:08   1/10/2016 15:51  Business     New York
# 22    1/12/2016 16:02   1/12/2016 17:00  Business     New York
# 97    2/12/2016 11:14   2/12/2016 11:35  Business  Morrisville
# 100   2/12/2016 15:33   2/12/2016 16:06  Business  Morrisville
# 106   2/14/2016 16:35   2/14/2016 17:02  Business     New York
# 388   5/28/2016 14:35   5/28/2016 15:04  Business  Morrisville
# 423   6/10/2016 15:19   6/10/2016 16:28  Business     New York
# 545   7/14/2016 16:03   7/14/2016 16:34  Business  Morrisville
# 546   7/14/2016 16:39   7/14/2016 20:05  Business  Morrisville
# 587   7/22/2016 15:49   7/22/2016 16:22  Business  Morrisville
# 604   7/27/2016 21:34   7/27/2016 21:57  Business  Morrisville
# 884  10/31/2016 18:47  10/31/2016 19:16  Business  Morrisville
#
#                 STOP*  MILES*         PURPOSE*
# 10             Queens    10.8          Meeting
# 22      Queens County    15.1          Meeting
# ...

# %% [markdown]
# ## 3. Sorting

# %%
data.sort_values(by=["MILES*"], ascending=False)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1155            Totals               NaN       NaN               NaN
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 881   10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 776    9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# ...                ...               ...       ...               ...
# 1121  12/27/2016 12:53  12/27/2016 12:57  Business           Kar?chi
# 1110  12/24/2016 22:04  12/24/2016 22:09  Business            Lahore
# 44     1/26/2016 17:27   1/26/2016 17:29  Business              Cary
# 420     6/8/2016 17:16    6/8/2016 17:18  Business              Soho
# 120    2/17/2016 16:38   2/17/2016 16:43  Business        Katunayaka
#
#                  STOP*   MILES*         PURPOSE*
# 1155               NaN  12204.7              NaN
# ...

# %%
data.sort_values(by=["START*"], ascending=True).head(5)
# Out:
#           START_DATE*         END_DATE* CATEGORY*  START*        STOP*  \
# 911   11/6/2016 10:50   11/6/2016 11:04  Business   Agnew  Renaissance
# 910   11/5/2016 19:20   11/5/2016 19:28  Business   Agnew        Agnew
# 906   11/4/2016 21:04   11/4/2016 21:20  Business   Agnew         Cory
# 908    11/5/2016 8:34    11/5/2016 8:43  Business   Agnew  Renaissance
# 879  10/30/2016 12:58  10/30/2016 13:18  Business  Almond  Bryson City
#
#      MILES* PURPOSE*
# 911     2.4      NaN
# 910     2.2      NaN
# 906     4.3      NaN
# 908     2.2      NaN
# 879    15.2      NaN

# %% [markdown]
# ## 4. Conditionally Adding Column

# %%
import numpy as np

# %%
data["DISTANCE"] = np.where(data["MILES*"] > 5, "Long Trip", "Short Trip")

# %%
data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*    DISTANCE
# 0     5.1   Meal/Entertain   Long Trip
# 1     5.0              NaN  Short Trip
# 2     4.8  Errand/Supplies  Short Trip
# 3     4.7          Meeting  Short Trip
# 4    63.7   Customer Visit   Long Trip

# %%
data["DISTANCE"].value_counts()
# Out:
# Long Trip     654
# Short Trip    502
# Name: DISTANCE, dtype: int64

# %%
data["YEAR"] = np.array("2020")
data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*    DISTANCE  YEAR
# 0          Fort Pierce      5.1   Meal/Entertain   Long Trip  2020
# ...

# %%
data["TIME_CAT"] = np.where(data["START_DATE*"] > "1/5/2016", "New Trip", "Old Trip")
data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*    DISTANCE  YEAR  TIME_CAT
# ...

# %% [markdown]
# ## Latihan 5

# %% [markdown]
# ### Soal 1 Buat kolom baru dengan kondisi berikut:
#     a) >10 : Long Trip
#     b) 5-10 : Medium trip
#     c) <5 : Short Trip

# %%
rules = [(data["MILES*"] > 10), ((data["MILES*"] < 10)&(data["MILES*"] >= 5)), (data["MILES*"] < 5)]
info = ["Long Trip", "Medium Trip", "Short Trip"]
data["Long Trip", "Medium Trip", "Short Trip"] = np.select(rules, info)
data.head(10)
# Out:
#        START_DATE*        END_DATE* CATEGORY*           START*  \
# 0   1/1/2016 21:11   1/1/2016 21:17  Business      Fort Pierce
# 1    1/2/2016 1:25    1/2/2016 1:37  Business      Fort Pierce
# 2   1/2/2016 20:25   1/2/2016 20:38  Business      Fort Pierce
# 3   1/5/2016 17:31   1/5/2016 17:45  Business      Fort Pierce
# 4   1/6/2016 14:42   1/6/2016 15:49  Business      Fort Pierce
# 5   1/6/2016 17:15   1/6/2016 17:19  Business  West Palm Beach
# 6   1/6/2016 17:30   1/6/2016 17:35  Business  West Palm Beach
# 7   1/7/2016 13:27   1/7/2016 13:33  Business             Cary
# 8   1/10/2016 8:05   1/10/2016 8:25  Business             Cary
# 9  1/10/2016 12:17  1/10/2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*    DISTANCE  YEAR  TIME_CAT  \
# 0      Fort Pierce     5.1   Meal/Entertain   Long Trip  2020  Old Trip
# 1      Fort Pierce     5.0              NaN  Short Trip  2020  Old Trip
# ...

# %% [markdown]
# # 5. Groupby Summarize

# %%
data.groupby("START*")["MILES*"].agg(["mean"]).head()
# Out:
#                 mean
# START*
# Agnew       2.775000
# Almond     15.200000
# Apex        5.341176
# Arabi      17.000000
# Arlington   4.900000

# %%
data.groupby("START*")["MILES*"].agg(["mean", "sum"]).head()
# Out:
#                 mean   sum
# START*
# Agnew       2.775000  11.1
# Almond     15.200000  15.2
# Apex        5.341176  90.8
# Arabi      17.000000  17.0
# Arlington   4.900000   4.9

# %% [markdown]
# ## Save DataFrame into CSV

# %%
data.to_csv("data_baru.csv")

# %% [markdown]
# #### Saving DF without index

# %%
data.to_csv("data_baru_noIndex.csv", index="false")
